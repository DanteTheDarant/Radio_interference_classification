# %%
import tensorflow as tf
from keras.models import Model
from keras.optimizers import Adam
from keras import layers, callbacks

from keras.utils import to_categorical

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import numpy as np

from tensorflow.python.keras.utils.vis_utils import plot_model
import pydot

from scipy.stats import norm
from scipy import stats
import os

from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.metrics import classification_report, ConfusionMatrixDisplay
import pickle
import dataframe_image as dfi
# Out:
# 2023-05-10 12:40:54.329277: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-05-10 12:40:54.356206: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# #### Save parameters

# %%
time_data_amount = 20
nr_classes = 3

using_weights = False

# %%
name = 'one_channel_test' #name of model - should be descriptive
save_folder = 'Reference_model_test_' + str(time_data_amount) #hyperparameter description her
if using_weights == True:
    save_folder = save_folder + '_W'
    name = name + '_weighted'

# %% [markdown]
# ### Gotta load in some data

# %%
datapath = '../../../All generated data/'
labelpath = '../../../All generated labels/'
data_list = os.listdir(datapath)
#print(data_list)

#all_data = [] #if we want to have data and labels in one list
all_datapoints = []
all_labels = []

total_channels = 79
total_scans_pr_sample = 20
classes = 3


for csv_file in data_list:
    data_file = datapath + csv_file
    current_data_file = pd.read_csv(data_file,header=None)

    label_file = labelpath + csv_file
    label_file = label_file.replace('.csv', '_labels.csv')
    current_label_file = pd.read_csv(label_file,header=None)

    for data_iter in range(len(current_data_file.index)):
        #Pulling out the data from a row and putting it in the list
        current_data_point = np.array(current_data_file.iloc[data_iter])
        current_data_point = current_data_point.reshape(total_scans_pr_sample,total_channels)
        all_datapoints.append(current_data_point)
        
        #adding the label to the datamatrix as the last row
        label_row = np.array(current_label_file.iloc[data_iter])
        label_row = label_row.reshape(1,total_channels)
        all_labels.append(label_row)
        
        #all_data.append(np.vstack([current_data_point, label_row])) #if we want to have data and labels in one list

# %%
print(all_labels[1].shape)
print(len(all_labels))
print(len(all_datapoints))
# Out:
# (1, 79)
# 10981
# 10981

# %% [markdown]
# #### Pick out one channel for each sample
# For now it takes the same channel for all samples

# %%
chosen_channels = list(range(1,78,3))

complete_data = []
complete_labels = []

for iter in range(len(all_datapoints)):
    for channel in chosen_channels:
        complete_data.append(all_datapoints[iter][0:time_data_amount,channel])
        complete_labels.append(all_labels[iter][:,channel])
    

#quick check to make sure it works
print(complete_data[1].shape)
print(len(complete_data))
print(complete_labels[1].shape)
print(len(complete_labels))
# Out:
# (20,)
# 285506
# (1,)
# 285506

# %% [markdown]
# ### Splits data in train and test

# %%
data_train, data_test, labels_train, labels_test = train_test_split(complete_data, complete_labels, train_size=0.8, random_state=112)

# One hot encoding
labels_test = to_categorical(labels_test)
labels_train = to_categorical(labels_train)

data_train = np.array(data_train)
data_test = np.array(data_test)
labels_train = np.array(labels_train)
labels_test = np.array(labels_test)
print(labels_test.shape)
# Out:
# (57102, 3)

# %% [markdown]
# ### Normalise data a bit

# %%
# Make a scaler from training data
scaler = preprocessing.StandardScaler().fit(data_train)

# scale everything using that scaler
data_train = scaler.transform(data_train)
data_test = scaler.transform(data_test)

# %% [markdown]
# ### Stuff for class weights

# %%
def generate_class_weights(class_series, multi_class=True, one_hot_encoded=False):
  """
  Method to generate class weights given a set of multi-class or multi-label labels, both one-hot-encoded or not.
  Some examples of different formats of class_series and their outputs are:
    - generate_class_weights(['mango', 'lemon', 'banana', 'mango'], multi_class=True, one_hot_encoded=False)
    {'banana': 1.3333333333333333, 'lemon': 1.3333333333333333, 'mango': 0.6666666666666666}
    - generate_class_weights([[1, 0, 0], [0, 1, 0], [0, 0, 1], [1, 0, 0]], multi_class=True, one_hot_encoded=True)
    {0: 0.6666666666666666, 1: 1.3333333333333333, 2: 1.3333333333333333}
    - generate_class_weights([['mango', 'lemon'], ['mango'], ['lemon', 'banana'], ['lemon']], multi_class=False, one_hot_encoded=False)
    {'banana': 1.3333333333333333, 'lemon': 0.4444444444444444, 'mango': 0.6666666666666666}
    - generate_class_weights([[0, 1, 1], [0, 0, 1], [1, 1, 0], [0, 1, 0]], multi_class=False, one_hot_encoded=True)
    {0: 1.3333333333333333, 1: 0.4444444444444444, 2: 0.6666666666666666}
  The output is a dictionary in the format { class_label: class_weight }. In case the input is one hot encoded, the class_label would be index
  of appareance of the label when the dataset was processed. 
  In multi_class this is np.unique(class_series) and in multi-label np.unique(np.concatenate(class_series)).
  Author: Angel Igareta (angel@igareta.com)
  """
  if multi_class:
    # If class is one hot encoded, transform to categorical labels to use compute_class_weight   
    if one_hot_encoded:
      class_series = np.argmax(class_series, axis=1)
  
    # Compute class weights with sklearn method
    class_labels = np.unique(class_series)
    class_weights = compute_class_weight(class_weight='balanced', classes=class_labels, y=class_series)
    return dict(zip(class_labels, class_weights))
  else:
    # It is neccessary that the multi-label values are one-hot encoded
    mlb = None
    if not one_hot_encoded:
      mlb = MultiLabelBinarizer()
      class_series = mlb.fit_transform(class_series)

    n_samples = len(class_series)
    n_classes = len(class_series[0])

    # Count each class frequency
    class_count = [0] * n_classes
    for classes in class_series:
        for index in range(n_classes):
            if classes[index] != 0:
                class_count[index] += 1
    
    # Compute class weights using balanced method
    class_weights = [n_samples / (n_classes * freq) if freq > 0 else 1 for freq in class_count]
    class_labels = range(len(class_weights)) if mlb is None else mlb.classes_
    return dict(zip(class_labels, class_weights))

# %%
class_weights = generate_class_weights(labels_train, multi_class=False, one_hot_encoded=True)

# %% [markdown]
# ## Building a model

# %%
signal_size = time_data_amount

y = layers.Input(shape=(signal_size,1), dtype='float32', name='Input')

x = layers.Conv1D(16, 3, padding='same', activation='relu', use_bias=True)(y)
#x = layers.Dropout(rate=0.1)(x)
x = layers.Conv1D(16, 3, padding='same', activation='relu')(x)
x = layers.MaxPool1D(pool_size=2,strides=2)(x)
x = layers.Conv1D(32, 3, padding='same', activation='relu')(x)

x = layers.Conv1D(32, 3, padding='same', activation='relu')(x)
x = layers.MaxPool1D(pool_size=3,strides=1)(x)



x = layers.Flatten()(x)
x = layers.Dropout(rate=0.4)(x)
x = layers.Dense(32, activation='relu')(x)
x = layers.Dropout(rate=0.4)(x)
x = layers.Dense(16,activation='relu')(x)
p = layers.Dense(classes, activation='softmax', name='p')(x)

model = Model(inputs=[y], outputs=[p])
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 20, 1)]           0
#
#  conv1d (Conv1D)             (None, 20, 16)            64
#
#  conv1d_1 (Conv1D)           (None, 20, 16)            784
#
#  max_pooling1d (MaxPooling1D  (None, 10, 16)           0
#  )
#
#  conv1d_2 (Conv1D)           (None, 10, 32)            1568
#
#  conv1d_3 (Conv1D)           (None, 10, 32)            3104
#
#  max_pooling1d_1 (MaxPooling  (None, 8, 32)            0
#  1D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense (Dense)               (None, 32)                8224
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_1 (Dense)             (None, 16)                528
#
#  p (Dense)                   (None, 3)                 51
#
# =================================================================
# Total params: 14,323
# Trainable params: 14,323
# Non-trainable params: 0
# _________________________________________________________________
# 2023-05-10 12:41:07.178528: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-10 12:41:07.186853: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-10 12:41:07.187006: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-10 12:41:07.188929: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-10 12:41:07.189059: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-10 12:41:07.189147: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-10 12:41:07.561345: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-10 12:41:07.561468: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-10 12:41:07.561530: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-10 12:41:07.561590: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3367 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
# ------------- model compilation --------------
ourAdam = Adam()
model.compile(optimizer=ourAdam, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Set the model training parameters
# Stop model training when the training loss is not dropped
callbacks_list = [callbacks.EarlyStopping(
                        monitor='val_loss', 
                        patience=50, 
                        verbose=0, 
                        mode='auto',
                        restore_best_weights=True,
                    )
                            ]

# ------------- Starting model Training --------------
BATCH_SIZE = 4096
EPOCH = 800

if using_weights == True:
    w_for_fit = class_weights
else:
    w_for_fit = None
    

hist = model.fit(data_train,labels_train, 
          batch_size = BATCH_SIZE, 
          epochs = EPOCH, 
          callbacks= callbacks_list,
          validation_split=0.25,
          class_weight=w_for_fit)
# Out:
# Epoch 1/800
# 2023-05-10 12:41:08.718145: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2023-05-10 12:41:09.268764: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 42/42 [==============================] - 3s 30ms/step - loss: 0.9064 - accuracy: 0.6364 - val_loss: 0.6963 - val_accuracy: 0.7231
# Epoch 2/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.6604 - accuracy: 0.7435 - val_loss: 0.6065 - val_accuracy: 0.7576
# Epoch 3/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.6155 - accuracy: 0.7571 - val_loss: 0.5895 - val_accuracy: 0.7630
# Epoch 4/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.5952 - accuracy: 0.7646 - val_loss: 0.5658 - val_accuracy: 0.7774
# Epoch 5/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.5727 - accuracy: 0.7790 - val_loss: 0.5419 - val_accuracy: 0.8005
# Epoch 6/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.5503 - accuracy: 0.7976 - val_loss: 0.5253 - val_accuracy: 0.8119
# Epoch 7/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.5358 - accuracy: 0.8077 - val_loss: 0.5085 - val_accuracy: 0.8181
# Epoch 8/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.5238 - accuracy: 0.8136 - val_loss: 0.5009 - val_accuracy: 0.8220
# Epoch 9/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.5168 - accuracy: 0.8170 - val_loss: 0.4921 - val_accuracy: 0.8264
# Epoch 10/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.5065 - accuracy: 0.8217 - val_loss: 0.4844 - val_accuracy: 0.8292
# Epoch 11/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.5017 - accuracy: 0.8236 - val_loss: 0.4824 - val_accuracy: 0.8304
# Epoch 12/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.4955 - accuracy: 0.8263 - val_loss: 0.4765 - val_accuracy: 0.8323
# Epoch 13/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.4902 - accuracy: 0.8280 - val_loss: 0.4782 - val_accuracy: 0.8307
# Epoch 14/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.4871 - accuracy: 0.8295 - val_loss: 0.4712 - val_accuracy: 0.8340
# Epoch 15/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.4838 - accuracy: 0.8310 - val_loss: 0.4677 - val_accuracy: 0.8369
# Epoch 16/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.
800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.4022 - accuracy: 0.8615 - val_loss: 0.4022 - val_accuracy: 0.8621
# Epoch 190/800
# 42/42 [==============================] - 0s 7ms/step - loss: 0.4001 - accuracy: 0.8621 - val_loss: 0.4026 - val_accuracy: 0.8611
# Epoch 191/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3993 - accuracy: 0.8624 - val_loss: 0.4007 - val_accuracy: 0.8621
# Epoch 192/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.4001 - accuracy: 0.8610 - val_loss: 0.4025 - val_accuracy: 0.8618
# Epoch 193/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3994 - accuracy: 0.8623 - val_loss: 0.4002 - val_accuracy: 0.8628
# Epoch 194/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3986 - accuracy: 0.8626 - val_loss: 0.4044 - val_accuracy: 0.8613
# Epoch 195/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3999 - accuracy: 0.8618 - val_loss: 0.4057 - val_accuracy: 0.8602
# Epoch 196/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.4008 - accuracy: 0.8621 - val_loss: 0.4013 - val_accuracy: 0.8624
# Epoch 197/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3984 - accuracy: 0.8630 - val_loss: 0.4007 - val_accuracy: 0.8621
# Epoch 198/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3982 - accuracy: 0.8625 - val_loss: 0.4024 - val_accuracy: 0.8623
# Epoch 199/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3977 - accuracy: 0.8633 - val_loss: 0.4020 - val_accuracy: 0.8616
# Epoch 200/800
# 42/42 [==============================] - 0s 7ms/step - loss: 0.3982 - accuracy: 0.8626 - val_loss: 0.4002 - val_accuracy: 0.8625
# Epoch 201/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3989 - accuracy: 0.8630 - val_loss: 0.4014 - val_accuracy: 0.8623
# Epoch 202/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3983 - accuracy: 0.8632 - val_loss: 0.3996 - val_accuracy: 0.8629
# Epoch 203/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3981 - accuracy: 0.8628 - val_loss: 0.4000 - val_accuracy: 0.8630
# Epoch 204/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3980 - accuracy: 0.8631 - val_loss: 0.4011 - val_accuracy: 0.8617
# Epoch 205/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3980 - accuracy: 0.8630 - val_loss: 0.3986 - val_accuracy: 0.8630
# Epoch 206/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3976 - accuracy: 0.8629 - val_loss: 0.4028 - val_accuracy: 0.8614
# Epoch 207/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3978 - accuracy: 0.8627 - val_loss: 0.4004 - val_accuracy: 0.8624
# Epoch 208/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3968 - accuracy: 0.8629 - val_loss: 0.3987 - val_accuracy: 0.8625
# Epoch 209/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3974 - accuracy: 0.8631 - val_loss: 0.3999 - val_accuracy: 0.8632
# Epoch 210/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3958 - accuracy: 0.8637 - val_loss: 0.4006 - val_accuracy: 0.8621
# Epoch 211/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3979 - accuracy: 0.8629 - val_loss: 0.3995 - val_accuracy: 0.8625
# Epoch 212/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3971 - accuracy: 0.8631 - val_loss: 0.3995 - val_accuracy: 0.8631
# Epoch 213/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3964 - accuracy: 0.8636 - val_loss: 0.4001 - val_accuracy: 0.8624
# Epoch 214/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3969 - accuracy: 0.8631 - val_loss: 0.3998 - val_accuracy: 0.8632
# Epoch 215/800
# 42/42 [==============================] - 0s 7ms/step - loss: 0.3984 - accuracy: 0.8628 - val_loss: 0.4067 - val_accuracy: 0.8590
# Epoch 216/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3978 - accuracy: 0.8633 - val_loss: 0.3994 - val_accuracy: 0.8630
# Epoch 217/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3975 - accuracy: 0.8627 - val_loss: 0.4007 - val_accuracy: 0.8617
# Epoch 218/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3962 - accuracy: 0.8636 - val_loss: 0.4043 - val_accuracy: 0.8603
# Epoch 219/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3965 - accuracy: 0.8630 - val_loss: 0.4001 - val_accuracy: 0.8629
# Epoch 220/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3955 - accuracy: 0.8633 - val_loss: 0.4006 - val_accuracy: 0.8620
# Epoch 221/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3958 - accuracy: 0.8633 - val_loss: 0.4003 - val_accuracy: 0.8619
# Epoch 222/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3975 - accuracy: 0.8628 - val_loss: 0.3997 - val_accuracy: 0.8630
# Epoch 223/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3953 - accuracy: 0.8639 - val_loss: 0.3978 - val_accuracy: 0.8632
# Epoch 224/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3954 - accuracy: 0.8636 - val_loss: 0.4005 - val_accuracy: 0.8622
# Epoch 225/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3961 - accuracy: 0.8637 - val_loss: 0.4001 - val_accuracy: 0.8625
# Epoch 226/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3959 - accuracy: 0.8637 - val_loss: 0.4028 - val_accuracy: 0.8604
# Epoch 227/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3947 - accuracy: 0.8643 - val_loss: 0.3990 - val_accuracy: 0.8633
# Epoch 228/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3954 - accuracy: 0.8642 - val_loss: 0.4030 - val_accuracy: 0.8612
# Epoch 229/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3952 - accuracy: 0.8635 - val_loss: 0.3981 - val_accuracy: 0.8624
# Epoch 230/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3952 - accuracy: 0.8636 - val_loss: 0.3994 - val_accuracy: 0.8626
# Epoch 231/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3956 - accuracy: 0.8639 - val_loss: 0.3994 - val_accuracy: 0.8632
# Epoch 232/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3946 - accuracy: 0.8640 - val_loss: 0.3998 - val_accuracy: 0.8620
# Epoch 233/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3937 - accuracy: 0.8641 - val_loss: 0.3967 - val_accuracy: 0.8634
# Epoch 234/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3943 - accuracy: 0.8641 - val_loss: 0.3996 - val_accuracy: 0.8625
# Epoch 235/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3951 - accuracy: 0.8642 - val_loss: 0.4015 - val_accuracy: 0.8615
# Epoch 236/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3941 - accuracy: 0.8639 - val_loss: 0.4005 - val_accuracy: 0.8627
# Epoch 237/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3943 - accuracy: 0.8644 - val_loss: 0.3975 - val_accuracy: 0.8634
# Epoch 238/800
# 42/42 [==============================] - 0s 9ms/step - loss: 0.3938 - accuracy: 0.8643 - val_loss: 0.3980 - val_accuracy: 0.8637
# Epoch 239/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3955 - accuracy: 0.8634 - val_loss: 0.3994 - val_accuracy: 0.8632
# Epoch 240/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3941 - accuracy: 0.8642 - val_loss: 0.3959 - val_accuracy: 0.8631
# Epoch 241/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3931 - accuracy: 0.8646 - val_loss: 0.3988 - val_accuracy: 0.8627
# Epoch 242/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3934 - accuracy: 0.8651 - val_loss: 0.3990 - val_accuracy: 0.8630
# Epoch 243/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3933 - accuracy: 0.8644 - val_loss: 0.4008 - val_accuracy: 0.8619
# Epoch 244/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3942 - accuracy: 0.8642 - val_loss: 0.3991 - val_accuracy: 0.8626
# Epoch 245/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3941 - accuracy: 0.8642 - val_loss: 0.3986 - val_accuracy: 0.8621
# Epoch 246/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3945 - accuracy: 0.8640 - val_loss: 0.3966 - val_accuracy: 0.8637
# Epoch 247/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3929 - accuracy: 0.8649 - val_loss: 0.3977 - val_accuracy: 0.8628
# Epoch 248/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3933 - accuracy: 0.8642 - val_loss: 0.4015 - val_accuracy: 0.8618
# Epoch 249/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3933 - accuracy: 0.8647 - val_loss: 0.3974 - val_accuracy: 0.8632
# Epoch 250/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3933 - accuracy: 0.8646 - val_loss: 0.4006 - val_accuracy: 0.8617
# Epoch 251/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3942 - accuracy: 0.8636 - val_loss: 0.3982 - val_accuracy: 0.8627
# Epoch 252/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3922 - accuracy: 0.8647 - val_loss: 0.3995 - val_accuracy: 0.8619
# Epoch 253/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3927 - accuracy: 0.8642 - val_loss: 0.3966 - val_accuracy: 0.8631
# Epoch 254/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3924 - accuracy: 0.8653 - val_loss: 0.3975 - val_accuracy: 0.8626
# Epoch 255/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3922 - accuracy: 0.8651 - val_loss: 0.3955 - val_accuracy: 0.8639
# Epoch 256/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3924 - accuracy: 0.8651 - val_loss: 0.3968 - val_accuracy: 0.8625
# Epoch 257/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3923 - accuracy: 0.8655 - val_loss: 0.3991 - val_accuracy: 0.8629
# Epoch 258/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3929 - accuracy: 0.8651 - val_loss: 0.3991 - val_accuracy: 0.8624
# Epoch 259/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3926 - accuracy: 0.8645 - val_loss: 0.4009 - val_accuracy: 0.8619
# Epoch 260/800
# 42/42 [==============================] - 0s 7ms/step - loss: 0.3931 - accuracy: 0.8644 - val_loss: 0.3977 - val_accuracy: 0.8631
# Epoch 261/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3922 - accuracy: 0.8649 - val_loss: 0.3969 - val_accuracy: 0.8626
# Epoch 262/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3905 - accuracy: 0.8659 - val_loss: 0.3946 - val_accuracy: 0.8644
# Epoch 263/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3913 - accuracy: 0.8654 - val_loss: 0.3955 - val_accuracy: 0.8637
# Epoch 264/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3917 - accuracy: 0.8653 - val_loss: 0.3980 - val_accuracy: 0.8619
# Epoch 265/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3920 - accuracy: 0.8648 - val_loss: 0.3959 - val_accuracy: 0.8638
# Epoch 266/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3913 - accuracy: 0.8654 - val_loss: 0.3971 - val_accuracy: 0.8632
# Epoch 267/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3912 - accuracy: 0.8653 - val_loss: 0.3962 - val_accuracy: 0.8643
# Epoch 268/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3910 - accuracy: 0.8651 - val_loss: 0.3967 - val_accuracy: 0.8632
# Epoch 269/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3924 - accuracy: 0.8645 - val_loss: 0.3965 - val_accuracy: 0.8634
# Epoch 270/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3922 - accuracy: 0.8645 - val_loss: 0.3954 - val_accuracy: 0.8645
# Epoch 271/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3897 - accuracy: 0.8659 - val_loss: 0.3962 - val_accuracy: 0.8636
# Epoch 272/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3903 - accuracy: 0.8653 - val_loss: 0.3963 - val_accuracy: 0.8633
# Epoch 273/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3913 - accuracy: 0.8647 - val_loss: 0.3988 - val_accuracy: 0.8622
# Epoch 274/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3901 - accuracy: 0.8652 - val_loss: 0.3949 - val_accuracy: 0.8637
# Epoch 275/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3918 - accuracy: 0.8646 - val_loss: 0.3973 - val_accuracy: 0.8632
# Epoch 276/800
# 42/42 [==============================] - 0s 7ms/step - loss: 0.3910 - accuracy: 0.8654 - val_loss: 0.3964 - val_accuracy: 0.8633
# Epoch 277/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3901 - accuracy: 0.8654 - val_loss: 0.3941 - val_accuracy: 0.8643
# Epoch 278/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3903 - accuracy: 0.8652 - val_loss: 0.3951 - val_accuracy: 0.8643
# Epoch 279/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3906 - accuracy: 0.8656 - val_loss: 0.3987 - val_accuracy: 0.8628
# Epoch 280/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3913 - accuracy: 0.8651 - val_loss: 0.3992 - val_accuracy: 0.8622
# Epoch 281/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3902 - accuracy: 0.8657 - val_loss: 0.3960 - val_accuracy: 0.8638
# Epoch 282/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3900 - accuracy: 0.8653 - val_loss: 0.3959 - val_accuracy: 0.8644
# Epoch 283/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3911 - accuracy: 0.8653 - val_loss: 0.3984 - val_accuracy: 0.8617
# Epoch 284/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3914 - accuracy: 0.8651 - val_loss: 0.4001 - val_accuracy: 0.8622
# Epoch 285/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3906 - accuracy: 0.8653 - val_loss: 0.3955 - val_accuracy: 0.8640
# Epoch 286/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3887 - accuracy: 0.8661 - val_loss: 0.3951 - val_accuracy: 0.8643
# Epoch 287/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3888 - accuracy: 0.8662 - val_loss: 0.3967 - val_accuracy: 0.8643
# Epoch 288/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3914 - accuracy: 0.8651 - val_loss: 0.3959 - val_accuracy: 0.8646
# Epoch 289/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3898 - accuracy: 0.8656 - val_loss: 0.3952 - val_accuracy: 0.8639
# Epoch 290/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3894 - accuracy: 0.8656 - val_loss: 0.3942 - val_accuracy: 0.8646
# Epoch 291/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3883 - accuracy: 0.8661 - val_loss: 0.3974 - val_accuracy: 0.8634
# Epoch 292/800
# 42/42 [==============================] - 0s 7ms/step - loss: 0.3899 - accuracy: 0.8658 - val_loss: 0.3980 - val_accuracy: 0.8628
# Epoch 293/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3897 - accuracy: 0.8655 - val_loss: 0.3965 - val_accuracy: 0.8644
# Epoch 294/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3880 - accuracy: 0.8665 - val_loss: 0.3961 - val_accuracy: 0.8643
# Epoch 295/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3882 - accuracy: 0.8664 - val_loss: 0.3974 - val_accuracy: 0.8625
# Epoch 296/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3902 - accuracy: 0.8653 - val_loss: 0.3950 - val_accuracy: 0.8635
# Epoch 297/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3877 - accuracy: 0.8664 - val_loss: 0.3945 - val_accuracy: 0.8640
# Epoch 298/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3881 - accuracy: 0.8660 - val_loss: 0.3927 - val_accuracy: 0.8653
# Epoch 299/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3887 - accuracy: 0.8660 - val_loss: 0.3943 - val_accuracy: 0.8648
# Epoch 300/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3881 - accuracy: 0.8663 - val_loss: 0.3979 - val_accuracy: 0.8634
# Epoch 301/800
# 42/42 [==============================] - 0s 7ms/step - loss: 0.3883 - accuracy: 0.8665 - val_loss: 0.3939 - val_accuracy: 0.8649
# Epoch 302/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3892 - accuracy: 0.8661 - val_loss: 0.3954 - val_accuracy: 0.8639
# Epoch 303/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3891 - accuracy: 0.8658 - val_loss: 0.3967 - val_accuracy: 0.8636
# Epoch 304/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3885 - accuracy: 0.8660 - val_loss: 0.3916 - val_accuracy: 0.8656
# Epoch 305/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3885 - accuracy: 0.8662 - val_loss: 0.3995 - val_accuracy: 0.8631
# Epoch 306/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3881 - accuracy: 0.8664 - val_loss: 0.3936 - val_accuracy: 0.8652
# Epoch 307/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3884 - accuracy: 0.8658 - val_loss: 0.3942 - val_accuracy: 0.8647
# Epoch 308/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3869 - accuracy: 0.8670 - val_loss: 0.3950 - val_accuracy: 0.8635
# Epoch 309/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3875 - accuracy: 0.8661 - val_loss: 0.3949 - val_accuracy: 0.8647
# Epoch 310/800
# 42/42 [==============================] - 0s 7ms/step - loss: 0.3880 - accuracy: 0.8666 - val_loss: 0.3976 - val_accuracy: 0.8631
# Epoch 311/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3881 - accuracy: 0.8660 - val_loss: 0.3962 - val_accuracy: 0.8644
# Epoch 312/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3890 - accuracy: 0.8662 - val_loss: 0.3941 - val_accuracy: 0.8648
# Epoch 313/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3891 - accuracy: 0.8663 - val_loss: 0.3949 - val_accuracy: 0.8643
# Epoch 314/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3881 - accuracy: 0.8662 - val_loss: 0.3940 - val_accuracy: 0.8650
# Epoch 315/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3875 - accuracy: 0.8666 - val_loss: 0.3959 - val_accuracy: 0.8647
# Epoch 316/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3875 - accuracy: 0.8667 - val_loss: 0.3950 - val_accuracy: 0.8638
# Epoch 317/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3886 - accuracy: 0.8665 - val_loss: 0.3934 - val_accuracy: 0.8649
# Epoch 318/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3882 - accuracy: 0.8662 - val_loss: 0.3929 - val_accuracy: 0.8649
# Epoch 319/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3893 - accuracy: 0.8658 - val_loss: 0.3959 - val_accuracy: 0.8640
# Epoch 320/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3879 - accuracy: 0.8663 - val_loss: 0.3931 - val_accuracy: 0.8650
# Epoch 321/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3868 - accuracy: 0.8668 - val_loss: 0.3948 - val_accuracy: 0.8649
# Epoch 322/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3884 - accuracy: 0.8659 - val_loss: 0.3982 - val_accuracy: 0.8630
# Epoch 323/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3894 - accuracy: 0.8658 - val_loss: 0.3939 - val_accuracy: 0.8642
# Epoch 324/800
# 42/42 [==============================] - 0s 7ms/step - loss: 0.3858 - accuracy: 0.8670 - val_loss: 0.3938 - val_accuracy: 0.8647
# Epoch 325/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3863 - accuracy: 0.8666 - val_loss: 0.3947 - val_accuracy: 0.8634
# Epoch 326/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3875 - accuracy: 0.8666 - val_loss: 0.3936 - val_accuracy: 0.8653
# Epoch 327/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3876 - accuracy: 0.8662 - val_loss: 0.3924 - val_accuracy: 0.8645
# Epoch 328/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3865 - accuracy: 0.8672 - val_loss: 0.3951 - val_accuracy: 0.8636
# Epoch 329/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3868 - accuracy: 0.8669 - val_loss: 0.3983 - val_accuracy: 0.8611
# Epoch 330/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3880 - accuracy: 0.8663 - val_loss: 0.3932 - val_accuracy: 0.8648
# Epoch 331/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3865 - accuracy: 0.8667 - val_loss: 0.3946 - val_accuracy: 0.8645
# Epoch 332/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3853 - accuracy: 0.8673 - val_loss: 0.3942 - val_accuracy: 0.8647
# Epoch 333/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3879 - accuracy: 0.8660 - val_loss: 0.3948 - val_accuracy: 0.8643
# Epoch 334/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3879 - accuracy: 0.8666 - val_loss: 0.3940 - val_accuracy: 0.8649
# Epoch 335/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3868 - accuracy: 0.8666 - val_loss: 0.3925 - val_accuracy: 0.8651
# Epoch 336/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3865 - accuracy: 0.8669 - val_loss: 0.3959 - val_accuracy: 0.8636
# Epoch 337/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3861 - accuracy: 0.8669 - val_loss: 0.3942 - val_accuracy: 0.8646
# Epoch 338/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3889 - accuracy: 0.8660 - val_loss: 0.3953 - val_accuracy: 0.8642
# Epoch 339/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3869 - accuracy: 0.8667 - val_loss: 0.3951 - val_accuracy: 0.8636
# Epoch 340/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3867 - accuracy: 0.8668 - val_loss: 0.3919 - val_accuracy: 0.8655
# Epoch 341/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3858 - accuracy: 0.8671 - val_loss: 0.3924 - val_accuracy: 0.8652
# Epoch 342/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3874 - accuracy: 0.8665 - val_loss: 0.3944 - val_accuracy: 0.8646
# Epoch 343/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3862 - accuracy: 0.8671 - val_loss: 0.3962 - val_accuracy: 0.8642
# Epoch 344/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3863 - accuracy: 0.8674 - val_loss: 0.3917 - val_accuracy: 0.8660
# Epoch 345/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3855 - accuracy: 0.8670 - val_loss: 0.3940 - val_accuracy: 0.8652
# Epoch 346/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3875 - accuracy: 0.8661 - val_loss: 0.3975 - val_accuracy: 0.8634
# Epoch 347/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3858 - accuracy: 0.8676 - val_loss: 0.3948 - val_accuracy: 0.8650
# Epoch 348/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3856 - accuracy: 0.8664 - val_loss: 0.3935 - val_accuracy: 0.8647
# Epoch 349/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3868 - accuracy: 0.8671 - val_loss: 0.3958 - val_accuracy: 0.8639
# Epoch 350/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3853 - accuracy: 0.8672 - val_loss: 0.3946 - val_accuracy: 0.8642
# Epoch 351/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3848 - accuracy: 0.8674 - val_loss: 0.3957 - val_accuracy: 0.8641
# Epoch 352/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3855 - accuracy: 0.8670 - val_loss: 0.3968 - val_accuracy: 0.8639
# Epoch 353/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3856 - accuracy: 0.8671 - val_loss: 0.4001 - val_accuracy: 0.8625
# Epoch 354/800
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3868 - accuracy: 0.8665 - val_loss: 0.3940 - val_accuracy: 0.8643

# %%
def createDir(path: str):
    isExist = os.path.exists(path)
    if not isExist:
        os.makedirs(path)
        print('Created "' + path + '" directory')
    else:
        print('"'+ path + '" directory already existed')

createDir(save_folder)
# Out:
# Created "Reference_model_test_20" directory

# %%
# Show loss curves
plt.figure()
plt.title('Training loss')
plt.plot(hist.epoch, hist.history['loss'], label='train loss')
plt.plot(hist.epoch, hist.history['val_loss'], label='val_loss')
plt.legend()
plt.savefig(save_folder + '/%s Training loss.pdf' %(name), format='pdf')
# plt.show()

plt.figure()
plt.title('Training acc')
plt.plot(hist.epoch, hist.history['accuracy'], label='train acc')
plt.plot(hist.epoch, hist.history['val_accuracy'], label='val_acc')
plt.legend()
plt.savefig(save_folder + '/%s Training acc.pdf' %(name), format='pdf')

# %%
evalDict = model.evaluate(data_test,labels_test)

# %%
from keras.utils.layer_utils import count_params
test = count_params(model.trainable_weights)

cre = open(save_folder + '/' + 'Params_' + str(test), 'x')
# Out:
# 1785/1785 [==============================] - 3s 2ms/step - loss: 0.3803 - accuracy: 0.8695

# %%
# Saving dict of history and evaluation result
with open(save_folder + '/' + 'histDict', 'wb') as file_pi:
    pickle.dump(hist.history, file_pi)

with open(save_folder + '/' + 'evalDict' + str(evalDict[1]), 'wb') as file_pi:
    pickle.dump(evalDict, file_pi)

# %%
#uncomment to save model
model.save(save_folder + '/' + name + '_Model')
# Out:
# 2023-05-10 13:11:10.264232: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,256]
# 	 [[{{node inputs}}]]
# 2023-05-10 13:11:10.271985: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# WARNING:absl:Function `_wrapped_model` contains input name(s) Input with unsupported characters which will be renamed to input in the SavedModel.
# 2023-05-10 13:11:10.467379: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,256]
# 	 [[{{node inputs}}]]
# 2023-05-10 13:11:10.484826: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Reference_model_test_20/one_channel_test_Model/assets
# INFO:tensorflow:Assets written to: Reference_model_test_20/one_channel_test_Model/assets

# %%
Y_test = np.argmax(labels_test, axis=1) # Convert one-hot to index
y_pred = np.argmax(model.predict(data_test),axis=1)
class_names = ['Empty channel', 'Wi-Fi', 'Bluetooth']
class_report = classification_report(Y_test, y_pred, target_names=class_names)
print(class_report)

with open(save_folder + '/' + 'classReportString', 'wb') as file_pi:
    pickle.dump(class_report, file_pi)
# Out:
# 1785/1785 [==============================] - 2s 1ms/step
#                precision    recall  f1-score   support
#
# Empty channel       0.87      0.99      0.92     35386
#         Wi-Fi       0.91      0.77      0.83     11353
#     Bluetooth       0.83      0.59      0.69     10363
#
#      accuracy                           0.87     57102
#     macro avg       0.87      0.78      0.81     57102
#  weighted avg       0.87      0.87      0.86     57102

# %%
ConfusionMatrixDisplay.from_predictions(Y_test, y_pred, normalize='true',cmap='Greens',colorbar=False, display_labels=class_names)
plt.title('Confusion Matrix')
plt.savefig(save_folder +'/confusion_matrix_'+ name +'.pdf', format='pdf')

# %%
class_reportDict = classification_report(Y_test, y_pred, output_dict=True, target_names=class_names)
for key in class_reportDict:
    try:
        class_reportDict[key]['Samples'] = class_reportDict[key].pop('support')
    except Exception as e:
        print(e)
print(class_reportDict)
# Out:
# 'float' object has no attribute 'pop'
# {'Empty channel': {'precision': 0.8676536451853695, 'recall': 0.9854462216695868, 'f1-score': 0.9228061818566741, 'Samples': 35386}, 'Wi-Fi': {'precision': 0.9062922516900676, 'recall': 0.7675504271998591, 'f1-score': 0.8311713086608166, 'Samples': 11353}, 'Bluetooth': {'precision': 0.831163491845964, 'recall': 0.5852552349705684, 'f1-score': 0.6868629671574179, 'Samples': 10363}, 'accuracy': 0.8694966901334454, 'macro avg': {'precision': 0.868369796240467, 'recall': 0.7794172946133381, 'f1-score': 0.8136134858916361, 'Samples': 57102}, 'weighted avg': {'precision': 0.8687134441519833, 'recall': 0.8694966901334454, 'f1-score': 0.8617678600934966, 'Samples': 57102}}

# %%
class_reportDict.pop('accuracy')
print(class_reportDict)
# Out:
# {'Empty channel': {'precision': 0.8676536451853695, 'recall': 0.9854462216695868, 'f1-score': 0.9228061818566741, 'Samples': 35386}, 'Wi-Fi': {'precision': 0.9062922516900676, 'recall': 0.7675504271998591, 'f1-score': 0.8311713086608166, 'Samples': 11353}, 'Bluetooth': {'precision': 0.831163491845964, 'recall': 0.5852552349705684, 'f1-score': 0.6868629671574179, 'Samples': 10363}, 'macro avg': {'precision': 0.868369796240467, 'recall': 0.7794172946133381, 'f1-score': 0.8136134858916361, 'Samples': 57102}, 'weighted avg': {'precision': 0.8687134441519833, 'recall': 0.8694966901334454, 'f1-score': 0.8617678600934966, 'Samples': 57102}}

# %%
df = pd.DataFrame(class_reportDict).transpose().round(decimals=3)
dfi.export(df, save_folder + '/' +name + "_ClassReport.png", table_conversion="matplotlib")
