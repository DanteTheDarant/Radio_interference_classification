# %%
import tensorflow as tf
from keras.models import Model
from keras.optimizers import Adam
from keras import layers, callbacks

from keras.utils import to_categorical

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import numpy as np

from tensorflow.python.keras.utils.vis_utils import plot_model
import pydot

from scipy.stats import norm
from scipy import stats
import os

from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.metrics import classification_report, ConfusionMatrixDisplay
from sklearn.utils.class_weight import compute_class_weight
import dataframe_image as dfi
import pickle
import math

from keras.utils.layer_utils import count_params
# Out:
# 2023-05-21 09:39:24.589610: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-05-21 09:39:24.615924: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
sfs = [1, 2, 4, 6, 8, 16, 32]
layer_options = [2, 3]
weight_options = [0, 1, 2] #options
extra_options = ['a', 'b']
nr_classes = 3
channel_width = 79

# %% [markdown]
# ### Gotta load in some data

# %%
datapath = 'All_data/'
labelpath = 'All_labels/'
data_list = os.listdir(datapath)
#print(data_list)

#all_data = [] #if we want to have data and labels in one list
complete_data = []
complete_labels = []

total_channels = 79
total_scans_pr_sample = 1


for csv_file in data_list:
    data_file = datapath + csv_file
    current_data_file = pd.read_csv(data_file,header=None)

    label_file = labelpath + csv_file
    label_file = label_file.replace('.csv', '_labels.csv')
    current_label_file = pd.read_csv(label_file,header=None)

    for data_iter in range(len(current_data_file.index)):
        #Pulling out the data from a row and putting it in the list
        current_data_point = np.array(current_data_file.iloc[data_iter])
        #current_data_point = current_data_point.reshape(total_scans_pr_sample,total_channels)
        complete_data.append(current_data_point)
        
        #adding the label to the datamatrix as the last row
        label_row = np.array(current_label_file.iloc[data_iter])
        #label_row = label_row.reshape(1,total_channels)
        complete_labels.append(label_row)
        
        #all_data.append(np.vstack([current_data_point, label_row])) #if we want to have data and labels in one list

        
data_train, data_test, labels_train, labels_test = train_test_split(complete_data, complete_labels, train_size=0.8, random_state=112)

data_train = np.array(data_train)
data_test = np.array(data_test)
labels_train = np.array(labels_train)
labels_test = np.array(labels_test)
print(labels_test.shape)

scaler = preprocessing.StandardScaler().fit(data_train)

# scale everything using that scaler
data_train = scaler.transform(data_train)
data_test = scaler.transform(data_test)

labels_test = to_categorical(labels_test)
labels_train = to_categorical(labels_train)
print(labels_test.shape)
# Out:
# (58140, 79)
# (58140, 79, 3)

# %%
def weighted_mean_squared_error(class_weight):
  def loss(y_true, y_pred):
          y_true = tf.dtypes.cast(y_true, tf.float32)
          y_pred = tf.dtypes.cast(y_pred, tf.float32)
#             y_pred=  tf.transpose(y_pred, perm=[1, 0,2])

          
          weight = tf.constant(class_weight, dtype=tf.float32)
          weight_per_sample = tf.transpose(tf.gather(weight, tf.argmax(y_true, axis=-1)))
          weight_per_sample = tf.expand_dims(weight_per_sample, axis=-1)
#             losses = tf.keras.losses.mean_squared_error(y_true, y_pred)
          losses = tf.math.square(y_true-y_pred)*weight_per_sample
          return tf.reduce_mean(losses, axis=-1)
  return loss

# %% [markdown]
# #### Pick out one channel for each sample
# For now it takes the same channel for all samples

# %%
for layerOpt in layer_options:
    for extraOpt in extra_options:
        for weightOpt in weight_options:
            for sf in sfs:
                if weightOpt == 0:
                    using_weights = False
                else:
                    using_weights = True

                name = 'multi_channels_test' #name of model - should be descriptive
                save_folder = 'sf'+ str(sf) + '_layerOpt' + str(layerOpt) + extraOpt  #hyperparameter description her
                if using_weights == True:
                    save_folder = save_folder + '_W'
                    name = name + '_weighted'
                    if weightOpt == 2:
                        save_folder = save_folder + 'crazier'


                if weightOpt == 2:
                    class_weights = [1.0, 5.0, 36.0]
                else: 
                    class_weights = [1.0, 5.0, 10.0]

                class_weights = np.array([class_weights[i] for i in range(len(class_weights))])

                signal_size = 1

                y = layers.Input(shape=(channel_width,1), dtype='float32', name='Input')
                x = layers.Conv1D(sf, 3, padding='same', activation='relu', use_bias=True)(y)
                for iter in range(layerOpt-1):
                    x = layers.Conv1D(sf, 3, padding='same', activation='relu')(x)

                x = layers.MaxPool1D(pool_size=2,strides=2)(x)
                for iter in range(layerOpt):
                    x = layers.Conv1D(sf*2, 3, padding='same', activation='relu')(x)

                x = layers.MaxPool1D(pool_size=2,strides=2)(x)
                for iter in range(layerOpt):
                    x = layers.Conv1D(sf*4, 3, padding='same', activation='relu')(x)
                #x = layers.Conv1D(sf*4, 3, padding='same', activation='relu')(x)
                x = layers.MaxPool1D(pool_size=2,strides=2)(x)
                
                if extraOpt == 'b': 
                    for iter in range(layerOpt):
                        x = layers.Conv1D(sf*8, 3, padding='same', activation='relu')(x)
                    x = layers.MaxPool1D(pool_size=2,strides=2)(x)
                
                x = layers.Flatten()(x)
                


                class_layer = [{}]*channel_width
                output_layer = [{}]*channel_width
                for iter in range(channel_width):
                    class_layer[iter] = layers.Dropout(rate=0.3)(x)
                    if sf < 3:
                        class_layer[iter] = layers.Dense(3,activation='relu')(class_layer[iter])
                    else: 
                        class_layer[iter] = layers.Dense(sf,activation='relu')(class_layer[iter])
                    class_layer[iter] = layers.Dropout(rate=0.3)(class_layer[iter])
                    #class_layer[iter] = layers.Dense(64,activation='relu')(class_layer[iter])
                    output_layer[iter] = layers.Dense(nr_classes, activation='softmax', name=('out'+str(iter)))(class_layer[iter])



                model = Model(inputs=[y], outputs=[out_layer for out_layer in output_layer])


                isExist = os.path.exists(save_folder)
                if not isExist:
                    os.makedirs(save_folder)
                    print('Created "' + save_folder + '" directory')
                else:
                    print('"'+ save_folder + '" directory already existed - skipping')
                    continue


                nr_params = count_params(model.trainable_weights)

                cre = open(save_folder + '/' + 'Params_' + str(nr_params), 'x')


                # ------------- model compilation --------------
                ourAdam = Adam()
                optimizer = tf.keras.optimizers.RMSprop()

                if using_weights == True:
                        loss_func = weighted_mean_squared_error(class_weights)
                else:
                        loss_func = 'categorical_crossentropy'

                metric_T = 'accuracy'
                loss_dict = {}
                metric_dict = {}
                for iter in range(channel_width):
                        loss_dict['out'+str(iter)] = loss_func
                        metric_dict['out'+str(iter)] = metric_T



                model.compile(optimizer=ourAdam, loss = loss_dict,
                              metrics=metric_T) 


                if nr_params > 1000000:
                    ting = 1
                elif nr_params > 500000:
                    ting = 2
                elif nr_params > 250000:
                    ting = 4    
                elif nr_params > 125000:
                    ting = 8
                elif nr_params < 50000:
                    ting = 32
                elif nr_params < 10000:
                    ting = 64
                else:
                    ting = 16


                BATCH_SIZE = 160*ting
                EPOCH = 600 + 75 * ting
                
                if ting > 15:
                    ekstra = 15
                elif ting < 4:
                    ekstra = 0
                else:
                    ekstra = ting

                # Set the model training parameters
                # Stop model training when the training loss is not dropped
                callbacks_list = [callbacks.EarlyStopping(
                                        monitor='val_loss', 
                                        patience=math.floor(10 + ekstra), 
                                        verbose=0, 
                                        mode='auto',
                                        restore_best_weights=True,
                                    )
                                            ]

                # ------------- Starting model Training --------------

                hist = model.fit(data_train,[labels_train[:,iter,:] for iter in range(channel_width)],
                          batch_size = BATCH_SIZE, 
                          epochs = EPOCH, 
                          callbacks= callbacks_list,
                          verbose=0,
                          validation_split=0.25)


                # Show loss curves
                fig1 = plt.figure()
                plt.title('Training loss')
                plt.plot(hist.epoch, hist.history['loss'], label='train loss')
                plt.plot(hist.epoch, hist.history['val_loss'], label='val_loss')
                plt.legend()
                plt.savefig(save_folder + '/%s Training loss.pdf' %(name), format='pdf')
                #plt.show()
                plt.close(fig1)

                fig2 = plt.figure()
                plt.title('Training accuracy')
                plt.xlabel("Epoch #")
                plt.ylabel("Accuracy")

                lossNames = ['out0_accuracy', 'out'+str(math.floor(channel_width/3))+'_accuracy', 'out'+str(math.floor(channel_width*2/3))+'_accuracy']
                for (i, l) in enumerate(lossNames):
                    # plot the loss for both the training and validation data
                    title = "Loss for {}".format(l) if l != "loss" else "Total loss"
                    plt.plot(hist.epoch, hist.history[l], label=l)
                    plt.plot(hist.epoch, hist.history["val_" + l],
                        label="val_" + l)
                    plt.legend()
                plt.savefig(save_folder + '/%s Training acc.pdf' %(name), format='pdf')
                #plt.show()
                plt.close(fig2)

                evalDict = model.evaluate(data_test,[labels_test[:,iter,:] for iter in range(channel_width)])
                totalA = 0
                for i in range(channel_width+1,channel_width+1+channel_width):
                    totalA += evalDict[i]

                totalA /= channel_width
                print(totalA)

                # Saving dict of history and evaluation result
                with open(save_folder + '/' + 'histDict', 'wb') as file_pi:
                    pickle.dump(hist.history, file_pi)

                with open(save_folder + '/' + 'evalDict' + str(totalA), 'wb') as file_pi:
                    pickle.dump(evalDict, file_pi)

                model.save(save_folder + '/' + name + '_Model')

                #Test on test data
                true_test_labels = np.argmax(labels_test, axis=-1)
                test_predictions = model.predict(data_test)
                test_result = np.argmax(test_predictions, axis=-1).T

                #classification report
                class_names = ['Empty channel', 'Wi-Fi', 'Bluetooth']
                class_report = classification_report(true_test_labels.flatten(), test_result.flatten(),target_names=class_names)

                with open(save_folder + '/' + 'classReportString', 'wb') as file_pi:
                    pickle.dump(class_report, file_pi)

                #Confusion matric plot
                plt.figure()
                ConfusionMatrixDisplay.from_predictions(true_test_labels.flatten(), test_result.flatten(),normalize='true',cmap='Greens',colorbar=False,display_labels=class_names)
                plt.title('Confusion Matrix')
                plt.savefig(save_folder +'/confusion_matrix_'+ name +'.pdf', format='pdf')
                plt.close()

                class_reportDict = classification_report(true_test_labels.flatten(), test_result.flatten(),output_dict=True, target_names=class_names)
                for key in class_reportDict:
                    try:
                        class_reportDict[key]['Samples'] = class_reportDict[key].pop('support')
                    except Exception as e:
                        print(e)
                #print(class_reportDict)
                class_reportDict.pop('accuracy')
                df = pd.DataFrame(class_reportDict).transpose().round(decimals=3)
                dfi.export(df, save_folder + '/' +name + "_ClassReport.png", table_conversion="matplotlib")
# Out:
# 2023-05-21 09:39:38.989979: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-21 09:39:38.993358: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-21 09:39:38.993468: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-21 09:39:38.994196: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-21 09:39:38.994284: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-21 09:39:38.994344: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-21 09:39:39.356546: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-21 09:39:39.356673: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-21 09:39:39.356736: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-21 09:39:39.356795: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3619 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# "sf1_layerOpt2a" directory already existed - skipping
# "sf2_layerOpt2a" directory already existed - skipping
# "sf4_layerOpt2a" directory already existed - skipping
# "sf6_layerOpt2a" directory already existed - skipping
# "sf8_layerOpt2a" directory already existed - skipping
# "sf16_layerOpt2a" directory already existed - skipping
# "sf32_layerOpt2a" directory already existed - skipping
# "sf1_layerOpt2a_W" directory already existed - skipping
# "sf2_layerOpt2a_W" directory already existed - skipping
# "sf4_layerOpt2a_W" directory already existed - skipping
# "sf6_layerOpt2a_W" directory already existed - skipping
# "sf8_layerOpt2a_W" directory already existed - skipping
# "sf16_layerOpt2a_W" directory already existed - skipping
# "sf32_layerOpt2a_W" directory already existed - skipping
# "sf1_layerOpt2a_Wcrazier" directory already existed - skipping
# "sf2_layerOpt2a_Wcrazier" directory already existed - skipping
# "sf4_layerOpt2a_Wcrazier" directory already existed - skipping
# "sf6_layerOpt2a_Wcrazier" directory already existed - skipping
# "sf8_layerOpt2a_Wcrazier" directory already existed - skipping
# "sf16_layerOpt2a_Wcrazier" directory already existed - skipping
# "sf32_layerOpt2a_Wcrazier" directory already existed - skipping
# "sf1_layerOpt2b" directory already existed - skipping
# "sf2_layerOpt2b" directory already existed - skipping
# "sf4_layerOpt2b" directory already existed - skipping
# "sf6_layerOpt2b" directory already existed - skipping
# "sf8_layerOpt2b" directory already existed - skipping
# "sf16_layerOpt2b" directory already existed - skipping
# "sf32_layerOpt2b" directory already existed - skipping
# "sf1_layerOpt2b_W" directory already existed - skipping
# "sf2_layerOpt2b_W" directory already existed - skipping
# "sf4_layerOpt2b_W" directory already existed - skipping
# "sf6_layerOpt2b_W" directory already existed - skipping
# "sf8_layerOpt2b_W" directory already existed - skipping
# "sf16_layerOpt2b_W" directory already existed - skipping
# "sf32_layerOpt2b_W" directory already existed - skipping
# "sf1_layerOpt2b_Wcrazier" directory already existed - skipping
# "sf2_layerOpt2b_Wcrazier" directory already existed - skipping
# "sf4_layerOpt2b_Wcrazier" directory already existed - skipping
# "sf6_layerOpt2b_Wcrazier" directory already existed - skipping
# "sf8_layerOpt2b_Wcrazier" directory already existed - skipping
# "sf16_layerOpt2b_Wcrazier" directory already existed - skipping
# "sf32_layerOpt2b_Wcrazier" directory already existed - skipping
# "sf1_layerOpt3a" directory already existed - skipping
# "sf2_layerOpt3a" directory already existed - skipping
# "sf4_layerOpt3a" directory already existed - skipping
# "sf6_layerOpt3a" directory already existed - skipping
# "sf8_layerOpt3a" directory already existed - skipping
# "sf16_layerOpt3a" directory already existed - skipping
# "sf32_layerOpt3a" directory already existed - skipping
# "sf1_layerOpt3a_W" directory already existed - skipping
# "sf2_layerOpt3a_W" directory already existed - skipping
# "sf4_layerOpt3a_W" directory already existed - skipping
# "sf6_layerOpt3a_W" directory already existed - skipping
# "sf8_layerOpt3a_W" directory already existed - skipping
# "sf16_layerOpt3a_W" directory already existed - skipping
# "sf32_layerOpt3a_W" directory already existed - skipping
# "sf1_layerOpt3a_Wcrazier" directory already existed - skipping
# "sf2_layerOpt3a_Wcrazier" directory already existed - skipping
# "sf4_layerOpt3a_Wcrazier" directory already existed - skipping
# "sf6_layerOpt3a_Wcrazier" directory already existed - skipping
# "sf8_layerOpt3a_Wcrazier" directory already existed - skipping
# "sf16_layerOpt3a_Wcrazier" directory already existed - skipping
# "sf32_layerOpt3a_Wcrazier" directory already existed - skipping
# "sf1_layerOpt3b" directory already existed - skipping
# Created "sf2_layerOpt3b" directory
# 2023-05-21 09:40:52.683287: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2023-05-21 09:40:53.601502: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 1817/1817 [==============================] - 42s 23ms/step - loss: 14.1715 - out0_loss: 0.0666 - out1_loss: 0.1703 - out2_loss: 0.1781 - out3_loss: 0.1586 - out4_loss: 0.1724 - out5_loss: 0.1383 - out6_loss: 0.2084 - out7_loss: 0.1745 - out8_loss: 0.1952 - out9_loss: 0.1535 - out10_loss: 0.2018 - out11_loss: 0.1696 - out12_loss: 0.2174 - out13_loss: 0.2022 - out14_loss: 0.1957 - out15_loss: 0.2059 - out16_loss: 0.2253 - out17_loss: 0.1825 - out18_loss: 0.2082 - out19_loss: 0.1914 - out20_loss: 0.2336 - out21_loss: 0.1828 - out22_loss: 0.2094 - out23_loss: 0.1932 - out24_loss: 0.2106 - out25_loss: 0.1920 - out26_loss: 0.2341 - out27_loss: 0.1834 - out28_loss: 0.2039 - out29_loss: 0.1875 - out30_loss: 0.2001 - out31_loss: 0.2325 - out32_loss: 0.2471 - out33_loss: 0.1977 - out34_loss: 0.2139 - out35_loss: 0.1971 - out36_loss: 0.2424 - out37_loss: 0.1837 - out38_loss: 0.2020 - out39_loss: 0.1898 - out40_loss: 0.2390 - out41_loss: 0.1979 - out42_loss: 0.2165 - out43_loss: 0.1901 - out44_loss: 0.2105 - out45_loss: 0.2203 - out46_loss: 0.2373 - out47_loss: 0.1850 - out48_loss: 0.2338 - out49_loss: 0.1894 - out50_loss: 0.2065 - out51_loss: 0.1933 - out52_loss: 0.2050 - out53_loss: 0.1845 - out54_loss: 0.2036 - out55_loss: 0.1886 - out56_loss: 0.2274 - out57_loss: 0.1649 - out58_loss: 0.1792 - out59_loss: 0.1980 - out60_loss: 0.1837 - out61_loss: 0.1689 - out62_loss: 0.1786 - out63_loss: 0.1639 - out64_loss: 0.2115 - out65_loss: 0.1637 - out66_loss: 0.2052 - out67_loss: 0.1661 - out68_loss: 0.1861 - out69_loss: 0.1430 - out70_loss: 0.1525 - out71_loss: 0.1321 - out72_loss: 0.1202 - out73_loss: 0.0545 - out74_loss: 0.0312 - out75_loss: 0.0322 - out76_loss: 0.0545 - out77_loss: 2.7475e-10 - out78_loss: 9.6797e-08 - out0_accuracy: 0.9839 - out1_accuracy: 0.9594 - out2_accuracy: 0.9544 - out3_accuracy: 0.9596 - out4_accuracy: 0.9547 - out5_accuracy: 0.9599 - out6_accuracy: 0.9415 - out7_accuracy: 0.9564 - out8_accuracy: 0.9501 - out9_accuracy: 0.9543 - out10_accuracy: 0.9486 - out11_accuracy: 0.9485 - out12_accuracy: 0.9448 - out13_accuracy: 0.9505 - out14_accuracy: 0.9452 - out15_accuracy: 0.9505 - out16_accuracy: 0.9338 - out17_accuracy: 0.9486 - out18_accuracy: 0.9411 - out19_accuracy: 0.9460 - out20_accuracy: 0.9426 - out21_accuracy: 0.9469 - out22_accuracy: 0.9390 - out23_accuracy: 0.9441 - out24_accuracy: 0.9389 - out25_accuracy: 0.9443 - out26_accuracy: 0.9279 - out27_accuracy: 0.9467 - out28_accuracy: 0.9414 - out29_accuracy: 0.9461 - out30_accuracy: 0.9408 - out31_accuracy: 0.9407 - out32_accuracy: 0.9384 - out33_accuracy: 0.9429 - out34_accuracy: 0.9379 - out35_accuracy: 0.9429 - out36_accuracy: 0.9262 - out37_accuracy: 0.9481 - out38_accuracy: 0.9429 - out39_accuracy: 0.9467 - out40_accuracy: 0.9408 - out41_accuracy: 0.9418 - out42_accuracy: 0.9417 - out43_accuracy: 0.9464 - out44_accuracy: 0.9405 - out45_accuracy: 0.9473 - out46_accuracy: 0.9288 - out47_accuracy: 0.9474 - out48_accuracy: 0.9433 - out49_accuracy: 0.9463 - out50_accuracy: 0.9411 - out51_accuracy: 0.9434 - out52_accuracy: 0.9414 - out53_accuracy: 0.9472 - out54_accuracy: 0.9416 - out55_accuracy: 0.9459 - out56_accuracy: 0.9305 - out57_accuracy: 0.9549 - out58_accuracy: 0.9511 - out59_accuracy: 0.9539 - out60_accuracy: 0.9499 - out61_accuracy: 0.9539 - out62_accuracy: 0.9526 - out63_accuracy: 0.9567 - out64_accuracy: 0.9514 - out65_accuracy: 0.9561 - out66_accuracy: 0.9523 - out67_accuracy: 0.9629 - out68_accuracy: 0.9579 - out69_accuracy: 0.9621 - out70_accuracy: 0.9568 - out71_accuracy: 0.9600 - out72_accuracy: 0.9756 - out73_accuracy: 0.9896 - out74_accuracy: 0.9894 - out75_accuracy: 0.9897 - out76_accuracy: 0.9896 - out77_accuracy: 1.0000 - out78_accuracy: 1.0000
# 0.9511223473126376
# 2023-05-21 09:59:58.374883: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.380371: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.385360: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.390403: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.395431: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.400506: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.405463: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.410564: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.415577: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.420638: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.425617: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.430525: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.435552: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.440546: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.445927: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.450869: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.455934: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.460983: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.466066: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.471096: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.476065: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.481054: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.486151: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.491153: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.496088: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.501151: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.506225: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.511283: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.516363: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.521253: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.526609: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.531623: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.536593: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.541483: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.546552: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.551584: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.556556: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.561600: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.566572: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.571623: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.576624: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.582207: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.587274: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.592660: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.597783: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.603334: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.608416: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.613467: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.618563: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.623619: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.628688: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.633718: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.638707: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.643697: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.648745: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.653814: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.658723: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.663748: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.668759: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.673719: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.678667: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.684113: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.689155: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.694189: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.699202: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.704191: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.709196: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.714295: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.719272: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.724161: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.729223: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.734268: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.739234: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.744273: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.749184: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.754239: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.759600: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.764622: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.769621: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:58.998809: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,3]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:59.004202: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,3]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:59.009261: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,3]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:59.014327: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,3]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:59.019381: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,3]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:59.024392: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,3]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:59.029386: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,3]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:59.034874: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,3]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:59.039794: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,3]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:59.044779: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,3]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:59.049836: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,3]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:59.055000: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,3]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:59.059967: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,3]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:59.065003: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,3]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:59.070032: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,3]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:59.075072: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,3]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:59.080131: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,3]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:59.085126: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,3]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:59.090215: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,3]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:59.095219: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,3]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:59.100250: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,3]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:59.105401: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,3]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:59.110396: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,3]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:59.115884: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,3]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:59.120946: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,3]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:59.125937: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,3]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:59.130846: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,3]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:59.135877: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,3]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:59.140838: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,3]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:59.145858: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,3]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:59.150910: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,3]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:59.155858: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,3]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:59.160898: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,3]
# 	 [[{{node inputs}}]]
# 2023-05-21 09:59:59.166000: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,3]
# ...
# 	 [[{{node inputs}}]]
# 2023-05-21 16:11:55.029003: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-05-21 16:11:55.040112: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-05-21 16:11:55.051123: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-05-21 16:11:55.062101: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-05-21 16:11:55.073097: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-05-21 16:11:55.084035: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-05-21 16:11:55.095908: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-05-21 16:11:55.107435: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-05-21 16:11:55.118459: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-05-21 16:11:55.129503: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-05-21 16:11:55.141165: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-05-21 16:11:55.152307: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-05-21 16:11:55.163366: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-05-21 16:11:55.174400: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-05-21 16:11:55.185472: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-05-21 16:11:55.196487: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-05-21 16:11:55.207625: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-05-21 16:11:55.218707: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-05-21 16:11:55.229690: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-05-21 16:11:55.240704: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-05-21 16:11:55.252252: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-05-21 16:11:55.263386: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-05-21 16:11:55.274372: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-05-21 16:11:55.285347: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-05-21 16:11:55.296389: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-05-21 16:11:55.308304: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-05-21 16:11:55.319780: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-05-21 16:11:55.330773: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-05-21 16:11:55.341822: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-05-21 16:11:55.352936: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-05-21 16:11:55.364491: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-05-21 16:11:55.375603: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-05-21 16:11:55.386648: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-05-21 16:11:55.397747: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-05-21 16:11:55.408847: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-05-21 16:11:55.419839: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-05-21 16:11:55.430924: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-05-21 16:11:55.441987: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-05-21 16:11:55.452968: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-05-21 16:11:55.463976: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-05-21 16:11:55.475493: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-05-21 16:11:55.486651: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-05-21 16:11:55.497656: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-05-21 16:11:55.508696: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-05-21 16:11:55.520602: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-05-21 16:11:55.531950: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-05-21 16:11:55.543044: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 12). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: sf32_layerOpt3b_Wcrazier/multi_channels_test_weighted_Model/assets
# INFO:tensorflow:Assets written to: sf32_layerOpt3b_Wcrazier/multi_channels_test_weighted_Model/assets
# 1817/1817 [==============================] - 11s 6ms/step
# 'float' object has no attribute 'pop'
